# %%
import pandas as pd

# %%
movies = pd.read_csv(r"C:\Users\arti\Desktop\dataset\IMDB_movies.csv")

# %%
movies.shape
# Out:
# (5043, 28)

# %%
movies.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# ...

# %%
pd.set_option('display.max_columns',28)
pd.set_option('display.min_rows',5)
movies.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi
# ...

# %%
movies.isnull().sum().sort_values(ascending=False)
# Out:
# gross                        884
# budget                       492
# aspect_ratio                 329
# content_rating               303
# plot_keywords                153
# title_year                   108
# director_name                104
# director_facebook_likes      104
# num_critic_for_reviews        50
# actor_3_name                  23
# actor_3_facebook_likes        23
# num_user_for_reviews          20
# color                         19
# duration                      15
# facenumber_in_poster          13
# actor_2_name                  13
# actor_2_facebook_likes        13
# language                      12
# actor_1_name                   7
# actor_1_facebook_likes         7
# country                        5
# cast_total_facebook_likes      0
# num_voted_users                0
# movie_title                    0
# movie_imdb_link                0
# genres                         0
# imdb_score                     0
# movie_facebook_likes           0
# dtype: int64

# %%
#write your code for row-wise null count here axis=1 means row in pandas
movies.isnull().sum(axis=1).sort_values(ascending=False)
# Out:
# 279     15
# 4       13
#         ..
# 1700     0
# 5042     0
# Length: 5043, dtype: int64

# %%
movies.isnull().sum().sort_values(ascending=False)/len(movies)*100
# Out:
# gross                        17.529248
# budget                        9.756098
# aspect_ratio                  6.523895
# content_rating                6.008328
# plot_keywords                 3.033908
# title_year                    2.141582
# director_name                 2.062265
# director_facebook_likes       2.062265
# num_critic_for_reviews        0.991473
# actor_3_name                  0.456078
# actor_3_facebook_likes        0.456078
# num_user_for_reviews          0.396589
# color                         0.376760
# duration                      0.297442
# facenumber_in_poster          0.257783
# actor_2_name                  0.257783
# actor_2_facebook_likes        0.257783
# language                      0.237954
# actor_1_name                  0.138806
# actor_1_facebook_likes        0.138806
# country                       0.099147
# cast_total_facebook_likes     0.000000
# num_voted_users               0.000000
# movie_title                   0.000000
# ...

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5043 entries, 0 to 5042
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   color                      5024 non-null   object
#  1   director_name              4939 non-null   object
#  2   num_critic_for_reviews     4993 non-null   float64
#  3   duration                   5028 non-null   float64
#  4   director_facebook_likes    4939 non-null   float64
#  5   actor_3_facebook_likes     5020 non-null   float64
#  6   actor_2_name               5030 non-null   object
#  7   actor_1_facebook_likes     5036 non-null   float64
#  8   gross                      4159 non-null   float64
#  9   genres                     5043 non-null   object
#  10  actor_1_name               5036 non-null   object
#  11  movie_title                5043 non-null   object
#  12  num_voted_users            5043 non-null   int64
# ...

# %%
#drop columns
movies_new=movies.drop(['color',
    'director_facebook_likes',
    'actor_1_facebook_likes',
    'actor_2_facebook_likes',
    'actor_3_facebook_likes',
    'actor_2_name',
    'cast_total_facebook_likes',
    'actor_3_name',
    'duration',
    'facenumber_in_poster',
    'content_rating',
    'country',
    'movie_imdb_link',
    'aspect_ratio',
    'plot_keywords'],axis=1)

# %%
movies_new.shape
# Out:
# (5043, 13)

# %%
movies_new.isnull().sum().sort_values(ascending=False)/len(movies_new)*100
# Out:
# gross                     17.529248
# budget                     9.756098
# title_year                 2.141582
# director_name              2.062265
# num_critic_for_reviews     0.991473
# num_user_for_reviews       0.396589
# language                   0.237954
# actor_1_name               0.138806
# genres                     0.000000
# movie_title                0.000000
# num_voted_users            0.000000
# imdb_score                 0.000000
# movie_facebook_likes       0.000000
# dtype: float64

# %%
#delet the rows in missing values
movies_new['gross'].isnull().sum()/len(movies_new['gross'])*100
# Out:
# 17.52924846321634

# %%
movies_new=movies_new[movies_new['gross'].notnull()]
movies_new=movies_new[movies_new['budget'].notnull()]

# %%
round(movies_new.isnull().sum().sort_values(ascending=False)/len(movies_new)*100,2)
# Out:
# actor_1_name              0.08
# language                  0.08
# num_critic_for_reviews    0.03
# director_name             0.00
# gross                     0.00
# genres                    0.00
# movie_title               0.00
# num_voted_users           0.00
# num_user_for_reviews      0.00
# budget                    0.00
# title_year                0.00
# imdb_score                0.00
# movie_facebook_likes      0.00
# dtype: float64

# %%
#drop unecessary rows
(movies_new.isnull().sum(axis=1).sort_values(ascending=False)>5).sum()
# Out:
# 0

# %%
movies_new=movies_new[movies_new.isnull().sum(axis=1).sort_values(ascending=False)<=5]
movies_new
# Out:
# C:\Users\arti\AppData\Local\Temp/ipykernel_5312/605869828.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   movies_new=movies_new[movies_new.isnull().sum(axis=1).sort_values(ascending=False)<=5]
#        director_name  num_critic_for_reviews        gross  \
# 0      James Cameron                   723.0  760505847.0
# 1     Gore Verbinski                   302.0  309404152.0
# ...              ...                     ...          ...
# 5037    Edward Burns                    14.0       4584.0
# 5042        Jon Gunn                    43.0      85222.0
#
#                                genres actor_1_name  \
# 0     Action|Adventure|Fantasy|Sci-Fi  CCH Pounder
# 1            Action|Adventure|Fantasy  Johnny Depp
# ...                               ...          ...
# 5037                     Comedy|Drama  Kerry Bishé
# 5042                      Documentary  John August
#
#                                     movie_title  num_voted_users  \
# ...

# %%
round(movies_new.isnull().sum().sort_values(ascending=False)/len(movies_new)*100,2)
# Out:
# actor_1_name              0.08
# language                  0.08
# num_critic_for_reviews    0.03
# director_name             0.00
# gross                     0.00
# genres                    0.00
# movie_title               0.00
# num_voted_users           0.00
# num_user_for_reviews      0.00
# budget                    0.00
# title_year                0.00
# imdb_score                0.00
# movie_facebook_likes      0.00
# dtype: float64

# %%
movies_new.groupby('language').language.count().sort_values(ascending=False)
# Out:
# language
# English       3707
# French          37
# Spanish         26
# Mandarin        15
# German          13
# Japanese        12
# Hindi           10
# Cantonese        8
# Italian          7
# Portuguese       5
# Korean           5
# Norwegian        4
# Dutch            3
# Persian          3
# Danish           3
# Hebrew           3
# Thai             3
# Indonesian       2
# Aboriginal       2
# Dari             2
# Czech            1
# Vietnamese       1
# Aramaic          1
# Telugu           1
# Swedish          1
# Bosnian          1
# Russian          1
# Romanian         1
# Arabic           1
# Icelandic        1
# Dzongkha         1
# None             1
# Mongolian        1
# Maya             1
# Filipino         1
# Hungarian        1
# Kazakh           1
# Zulu             1
# Name: language, dtype: int64

# %%
movies_new.language.describe()
# Out:
# count        3888
# unique         38
# top       English
# freq         3707
# Name: language, dtype: object

# %%
movies_new.language=movies_new.language.fillna('english')

# %%
round(movies_new.isnull().sum().sort_values(ascending=False)/len(movies_new)*100,2)
# Out:
# actor_1_name              0.08
# num_critic_for_reviews    0.03
# director_name             0.00
# gross                     0.00
# genres                    0.00
# movie_title               0.00
# num_voted_users           0.00
# num_user_for_reviews      0.00
# language                  0.00
# budget                    0.00
# title_year                0.00
# imdb_score                0.00
# movie_facebook_likes      0.00
# dtype: float64

# %%
print(len(movies_new['actor_1_name']))
# Out:
# 3856

# %%
len(movies_new)/len(movies)*100
# Out:
# 77.15645449137418

# %%
#data analysis
#write your code for unit convert here budget and gross cnvert in to $to million $
movies_new['budget']=movies_new['budget']/1000000
movies_new['gross']=movies_new['gross']/1000000

# %%
movies_new
# Out:
#        director_name  num_critic_for_reviews       gross  \
# 0      James Cameron                   723.0  760.505847
# 1     Gore Verbinski                   302.0  309.404152
# ...              ...                     ...         ...
# 5037    Edward Burns                    14.0    0.004584
# 5042        Jon Gunn                    43.0    0.085222
#
#                                genres actor_1_name  \
# 0     Action|Adventure|Fantasy|Sci-Fi  CCH Pounder
# 1            Action|Adventure|Fantasy  Johnny Depp
# ...                               ...          ...
# 5037                     Comedy|Drama  Kerry Bishé
# 5042                      Documentary  John August
#
#                                     movie_title  num_voted_users  \
# 0                                       Avatar            886204
# 1     Pirates of the Caribbean: At World's End            471220
# ...                                         ...              ...
# ...

# %%
#highes movies profit
movies_new['profit']=movies_new['gross']-movies_new['budget']

# %%
top_10=movies_new.sort_values(by='profit',ascending=False).head(10)
top_10
# Out:
#           director_name  num_critic_for_reviews       gross  \
# 0         James Cameron                   723.0  760.505847
# 29      Colin Trevorrow                   644.0  652.177271
# 26        James Cameron                   315.0  658.672302
# 3024       George Lucas                   282.0  460.935665
# 3080   Steven Spielberg                   215.0  434.949459
# 794         Joss Whedon                   703.0  623.279547
# 17          Joss Whedon                   703.0  623.279547
# 509        Roger Allers                   186.0  422.783777
# 240        George Lucas                   320.0  474.544677
# 66    Christopher Nolan                   645.0  533.316061
#
#                                         genres         actor_1_name  \
# 0              Action|Adventure|Fantasy|Sci-Fi          CCH Pounder
# 29            Action|Adventure|Sci-Fi|Thriller  Bryce Dallas Howard
# 26                               Drama|Romance    Leonardo DiCaprio
# ...

# %%
top_10.shape
top_10
# Out:
#           director_name  num_critic_for_reviews       gross  \
# 0         James Cameron                   723.0  760.505847
# 29      Colin Trevorrow                   644.0  652.177271
# 26        James Cameron                   315.0  658.672302
# 3024       George Lucas                   282.0  460.935665
# 3080   Steven Spielberg                   215.0  434.949459
# 794         Joss Whedon                   703.0  623.279547
# 17          Joss Whedon                   703.0  623.279547
# 509        Roger Allers                   186.0  422.783777
# 240        George Lucas                   320.0  474.544677
# 66    Christopher Nolan                   645.0  533.316061
#
#                                         genres         actor_1_name  \
# 0              Action|Adventure|Fantasy|Sci-Fi          CCH Pounder
# 29            Action|Adventure|Sci-Fi|Thriller  Bryce Dallas Howard
# 26                               Drama|Romance    Leonardo DiCaprio
# ...

# %%
#remove duplicated
movies_new.drop_duplicates(keep='first',inplace=True)
movies_new
# Out:
#        director_name  num_critic_for_reviews       gross  \
# 0      James Cameron                   723.0  760.505847
# 1     Gore Verbinski                   302.0  309.404152
# ...              ...                     ...         ...
# 5037    Edward Burns                    14.0    0.004584
# 5042        Jon Gunn                    43.0    0.085222
#
#                                genres actor_1_name  \
# 0     Action|Adventure|Fantasy|Sci-Fi  CCH Pounder
# 1            Action|Adventure|Fantasy  Johnny Depp
# ...                               ...          ...
# 5037                     Comedy|Drama  Kerry Bishé
# 5042                      Documentary  John August
#
#                                     movie_title  num_voted_users  \
# 0                                       Avatar            886204
# 1     Pirates of the Caribbean: At World's End            471220
# ...                                         ...              ...
# ...

# %%
top_10=movies_new.sort_values(by='profit',ascending=False).head(10)
top_10
# Out:
#           director_name  num_critic_for_reviews       gross  \
# 0         James Cameron                   723.0  760.505847
# 29      Colin Trevorrow                   644.0  652.177271
# 26        James Cameron                   315.0  658.672302
# 3024       George Lucas                   282.0  460.935665
# 3080   Steven Spielberg                   215.0  434.949459
# 17          Joss Whedon                   703.0  623.279547
# 509        Roger Allers                   186.0  422.783777
# 240        George Lucas                   320.0  474.544677
# 66    Christopher Nolan                   645.0  533.316061
# 439           Gary Ross                   673.0  407.999255
#
#                                         genres         actor_1_name  \
# 0              Action|Adventure|Fantasy|Sci-Fi          CCH Pounder
# 29            Action|Adventure|Sci-Fi|Thriller  Bryce Dallas Howard
# 26                               Drama|Romance    Leonardo DiCaprio
# ...

# %%
#highest reting and votters 
imdb_top250=movies_new[movies_new['num_voted_users']>25000].sort_values(by='imdb_score',ascending=False).head(250)

# %%
imdb_top250['rank']=imdb_top250['imdb_score'].rank(method='first',ascending=False)
imdb_top250
# Out:
#              director_name  num_critic_for_reviews       gross  \
# 1937        Frank Darabont                   199.0   28.341469
# 3466  Francis Ford Coppola                   208.0  134.821952
# ...                    ...                     ...         ...
# 2177            Tim Burton                   111.0   56.362352
# 2487          George Cukor                    82.0   72.000000
#
#                             genres    actor_1_name                movie_title  \
# 1937                   Crime|Drama  Morgan Freeman  The Shawshank Redemption
# 3466                   Crime|Drama       Al Pacino             The Godfather
# ...                            ...             ...                        ...
# 2177               Fantasy|Romance     Johnny Depp       Edward Scissorhands
# 2487  Drama|Family|Musical|Romance    Jeremy Brett              My Fair Lady
#
#       num_voted_users num_user_for_reviews language  budget  title_year  \
# ...

# %%
imdb_top250[imdb_top250['language']!='English']
# Out:
#                          director_name  num_critic_for_reviews       gross  \
# 4498                      Sergio Leone                   181.0    6.100000
# 4747                    Akira Kurosawa                   153.0    0.269061
# 4029                Fernando Meirelles                   214.0    7.563397
# 2373                    Hayao Miyazaki                   246.0   10.049886
# 4259  Florian Henckel von Donnersmarck                   215.0   11.284657
# 4921                      Majid Majidi                    46.0    0.925402
# 2323                    Hayao Miyazaki                   174.0    2.298191
# 2970                 Wolfgang Petersen                    96.0   11.433134
# 4105                    Chan-wook Park                   305.0    2.181290
# 4659                    Asghar Farhadi                   354.0    7.098492
# 1329                    S.S. Rajamouli                    44.0    6.498000
# ...

# %%
top10_director=movies_new.groupby('director_name').imdb_score.mean().sort_values(ascending=False).head(10)

# %%
#find the popular gener
# only take two
temp_genre=movies_new.genres.str.split('|',expand=True).iloc[:,0:2]
temp_genre.columns=['genre_1','genre_2']
#fill value gen2 from gen1
temp_genre.genre_2.fillna(temp_genre.genre_1,inplace=True)
temp_genre
# Out:
#           genre_1      genre_2
# 0          Action    Adventure
# 1          Action    Adventure
# ...           ...          ...
# 5037       Comedy        Drama
# 5042  Documentary  Documentary
#
# [3856 rows x 2 columns]

# %%
movies_new
# Out:
#        director_name  num_critic_for_reviews       gross  \
# 0      James Cameron                   723.0  760.505847
# 1     Gore Verbinski                   302.0  309.404152
# ...              ...                     ...         ...
# 5037    Edward Burns                    14.0    0.004584
# 5042        Jon Gunn                    43.0    0.085222
#
#                                genres actor_1_name  \
# 0     Action|Adventure|Fantasy|Sci-Fi  CCH Pounder
# 1            Action|Adventure|Fantasy  Johnny Depp
# ...                               ...          ...
# 5037                     Comedy|Drama  Kerry Bishé
# 5042                      Documentary  John August
#
#                                     movie_title  num_voted_users  \
# 0                                       Avatar            886204
# 1     Pirates of the Caribbean: At World's End            471220
# ...                                         ...              ...
# ...

# %%
movies_new=pd.concat([movies_new,temp_genre],axis=1)
movies_new
# Out:
#        director_name  num_critic_for_reviews       gross  \
# 0      James Cameron                   723.0  760.505847
# 1     Gore Verbinski                   302.0  309.404152
# ...              ...                     ...         ...
# 5037    Edward Burns                    14.0    0.004584
# 5042        Jon Gunn                    43.0    0.085222
#
#                                genres actor_1_name  \
# 0     Action|Adventure|Fantasy|Sci-Fi  CCH Pounder
# 1            Action|Adventure|Fantasy  Johnny Depp
# ...                               ...          ...
# 5037                     Comedy|Drama  Kerry Bishé
# 5042                      Documentary  John August
#
#                                     movie_title  num_voted_users  \
# 0                                       Avatar            886204
# 1     Pirates of the Caribbean: At World's End            471220
# ...                                         ...              ...
# ...

# %%
movies_new.groupby(['genre_1','genre_2']).gross.mean().sort_values(ascending=False).head(5)
# Out:
# genre_1    genre_2
# Family     Sci-Fi       434.949459
# Adventure  Sci-Fi       228.627758
#            Family       118.919540
#            Animation    116.998550
# Action     Adventure    109.595465
# Name: gross, dtype: float64

# %%
# Write your code for creating three new dataframes here
Meryl_Streep = movies_new[movies_new['actor_1_name']=='Meryl Streep']
Leo_Caprio = movies_new[movies_new['actor_1_name']=='Leonardo DiCaprio']
Brad_Pitt = movies_new[movies_new['actor_1_name']=='Brad Pitt']
Combined = Meryl_Streep.append([Leo_Caprio,Brad_Pitt])

# %%
Combined.groupby('actor_1_name').num_critic_for_reviews.mean()
# Out:
# actor_1_name
# Brad Pitt            245.000000
# Leonardo DiCaprio    330.190476
# Meryl Streep         181.454545
# Name: num_critic_for_reviews, dtype: float64

# %%
Combined.num_user_for_reviews = Combined.num_user_for_reviews.astype('int')
Combined.num_user_for_reviews
# Out:
# 410      214
# 1106      69
# 1204     277
# 1408     631
# 1483     298
# 1575     200
# 1618     178
# 1674     112
# 1925     660
# 2781     350
# 3135     280
# 26      2528
# 50       753
# 97      2803
# 179     1188
# 257      799
# 296     1193
# 307      657
# 308     1138
# 326     1166
# 361     2054
# 452      964
# 641      263
# 911      667
# 990      548
# 1114     414
# 1422     244
# 1453     279
# 1560     216
# 2067      71
# 2757     506
# 3476     753
# 101      822
# 147     1694
# 254      627
# 255      798
# 382      361
# 400      845
# 470      701
# 611      119
# 683     2968
# 792       91
# 940      406
# 1490     975
# 1722     415
# 2204     908
# 2333      61
# 2682     369
# 2898     460
# Name: num_user_for_reviews, dtype: int32

# %%
Combined.groupby('actor_1_name').num_user_for_reviews.mean()
# Out:
# actor_1_name
# Brad Pitt            742.352941
# Leonardo DiCaprio    914.476190
# Meryl Streep         297.181818
# Name: num_user_for_reviews, dtype: float64

# %%
Combined.groupby('actor_1_name')[['num_critic_for_reviews','num_user_for_reviews']].mean()
# Out:
#                    num_critic_for_reviews  num_user_for_reviews
# actor_1_name
# Brad Pitt                      245.000000            742.352941
# Leonardo DiCaprio              330.190476            914.476190
# Meryl Streep                   181.454545            297.181818
